# %% [markdown]
# <a href="https://colab.research.google.com/github/Aniket-a14/AI_friend/blob/main/notebooks/ai_friend_voice_training.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 👇 Just Click the Play Button (Run) and Wait for Public Gradio Link

# %%
# @title 🛠️ AI Friend: AI Friend Voice Trainer (April 2026)
# %cd /content
# !rm -rf GPT-SoVITS
# !git clone https://github.com/RVC-Boss/GPT-SoVITS.git
# %cd /content/GPT-SoVITS

# 1. Standard 2026 System Setup
# !apt-get install -y ffmpeg cmake

# 2. Modern Dependency Management (Avoiding 2025 version conflicts)
# !pip install --upgrade pip
# !pip install setuptools wheel numba librosa==0.10.1 gradio==4.44.1 ffmpeg-python onnxruntime-gpu
# !pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu121

# 3. Clean up requirements for the April 2026 environment
# !grep -v "opencc" requirements.txt > req_2026.txt
# !pip install -r req_2026.txt

# 4. Grab the V2/V3 Pretrained Base Models
# !mkdir -p GPT_SoVITS/pretrained_models
# !wget https://huggingface.co/lj1995/GPT-SoVITS/resolve/main/gsv-v2final-pretrained/s1v2full-hotdistill-2dd8d31d.ckpt -O GPT_SoVITS/pretrained_models/s1v2full-hotdistill-2dd8d31d.ckpt
# !wget https://huggingface.co/lj1995/GPT-SoVITS/resolve/main/gsv-v2final-pretrained/s2G488k.pth -O GPT_SoVITS/pretrained_models/s2G488k.pth
# !wget https://huggingface.co/lj1995/GPT-SoVITS/resolve/main/gsv-v2final-pretrained/s2D488k.pth -O GPT_SoVITS/pretrained_models/s2D488k.pth

# 5. Launch
# !python webui.py
