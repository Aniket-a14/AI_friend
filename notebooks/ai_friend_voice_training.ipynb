# %% [markdown]
# # 🎙️ AI Friend: Pankudi Voice Training Notebook (April 2026)
#
# This notebook contains the optimized setup for fine-tuning your dedicated `pankudi_voice` model in Google Colab.

# %%
# @title 🚀 1. Launch Training WebUI (April 2026 Fix)
# %cd /content
# !rm -rf GPT-SoVITS
# !git clone https://github.com/RVC-Boss/GPT-SoVITS.git
# %cd /content/GPT-SoVITS

# System Setup
# !apt-get install -y ffmpeg cmake
# !pip install --upgrade pip setuptools wheel
# !pip install numba librosa==0.10.1 gradio==4.44.1 ffmpeg-python onnxruntime-gpu
# !pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu121
# !grep -v "opencc" requirements.txt > req_2026.txt
# !pip install -r req_2026.txt

# Download Pretrained Weights
# !mkdir -p GPT_SoVITS/pretrained_models/gsv-v2final-pretrained
# %cd GPT_SoVITS/pretrained_models/gsv-v2final-pretrained
# !wget "https://huggingface.co/lj1995/GPT-SoVITS/resolve/main/gsv-v2final-pretrained/s1bert25hz-5kh-longer-epoch=12-step=369668.ckpt" -O s1v2.ckpt
# !wget "https://huggingface.co/lj1995/GPT-SoVITS/resolve/main/gsv-v2final-pretrained/s2G2333k.pth" -O s2G488k.pth
# !wget "https://huggingface.co/lj1995/GPT-SoVITS/resolve/main/gsv-v2final-pretrained/s2D2333k.pth" -O s2D488k.pth
# %cd /content/GPT-SoVITS

# Launch
# !python webui.py

# %% [markdown]
# ### 🔎 Instructions:
# 1. Run the cell above.
# 2. If it asks to **'Restart Runtime'**, click the button and run the cell again.
# 3. Open the **`gradio.live`** link that appears at the bottom.
# 4. Follow the **[Training Guide](https://github.com/Aniket-a14/AI_friend/blob/main/docs/TRAINING_GUIDE.md)** for the rest of the steps.
